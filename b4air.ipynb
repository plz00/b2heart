# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("AirQualityUCI.csv")

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/3/2004  18:00:00     2.6         1360       150      11.9
# 1     10/3/2004  19:00:00     2.0         1292       112       9.4
# 2     10/3/2004  20:00:00     2.2         1402        88       9.0
# 3     10/3/2004  21:00:00     2.2         1376        80       9.2
# 4     10/3/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
df=df.rename (columns={'T': 'Temperature'})
df=df.rename(columns={'RH': 'Relative Humidity'})
df=df.rename(columns={'AH': 'Absolute Humidity'})
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/3/2004  18:00:00     2.6         1360       150      11.9
# 1     10/3/2004  19:00:00     2.0         1292       112       9.4
# 2     10/3/2004  20:00:00     2.2         1402        88       9.0
# 3     10/3/2004  21:00:00     2.2         1376        80       9.2
# 4     10/3/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
df['CO(GT)'] = pd.to_numeric(df['CO(GT)'].astype(str).str.replace(',', '.'), errors='coerce')
df['C6H6(GT)'] = pd.to_numeric(df['C6H6(GT)'].astype(str).str.replace(',', '.'), errors='coerce')
df['Temperature'] = pd.to_numeric(df['Temperature'].astype(str).str.replace(',', '.'), errors='coerce')
df['Relative Humidity'] = pd.to_numeric(df['Relative Humidity'].astype(str).str.replace(',', '.'), errors='coerce')
df['Absolute Humidity'] = pd.to_numeric(df['Absolute Humidity'].astype(str).str.replace(',', '.'), errors='coerce')
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/3/2004  18:00:00     2.6         1360       150      11.9
# 1     10/3/2004  19:00:00     2.0         1292       112       9.4
# 2     10/3/2004  20:00:00     2.2         1402        88       9.0
# 3     10/3/2004  21:00:00     2.2         1376        80       9.2
# 4     10/3/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
df.dropna().sum()
# Out:
# Date                 10/3/200410/3/200410/3/200410/3/200410/3/20041...
# Time                 18:00:0019:00:0020:00:0021:00:0022:00:0023:00:...
# CO(GT)                                                       -320079.8
# PT08.S1(CO)                                                    9815400
# NMHC(GT)                                                      -1488606
# C6H6(GT)                                                       17457.2
# PT08.S2(NMHC)                                                  8370728
# NOx(GT)                                                        1577749
# PT08.S3(NOx)                                                   7438723
# NO2(GT)                                                         544099
# PT08.S4(NO2)                                                  13020075
# PT08.S5(O3)                                                    9123749
# Temperature                                                    91495.6
# ...

# %%
df['Absolute Humidity']=df['Absolute Humidity'].multiply(100)
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/3/2004  18:00:00     2.6         1360       150      11.9
# 1     10/3/2004  19:00:00     2.0         1292       112       9.4
# 2     10/3/2004  20:00:00     2.2         1402        88       9.0
# 3     10/3/2004  21:00:00     2.2         1376        80       9.2
# 4     10/3/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
plt.figure(figsize=(10, 6))
numerical_df = df.select_dtypes(include=np.number)  
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.lineplot(df,x="Time", y= 'Absolute Humidity')
# Out:
# C:\Users\cjich\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\cjich\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Time', ylabel='Absolute Humidity'>

# %%
sns.barplot(df,x=df.Time,y=df.Temperature)
# Out:
# <Axes: xlabel='Time', ylabel='Temperature'>

# %%
sns.scatterplot (df, x= 'PT08.S1(CO)', y='PT08.S3(NOx)', hue='Time')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S3(NOx)'>
