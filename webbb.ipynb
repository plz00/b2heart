# %%
import requests
from bs4 import BeautifulSoup
import json
import bs4

# %%
request1=requests.get('https://www.flipkart.com/flipkart/p/item?pid=MIXEJ9YXZ9PAU6JU&lid=LSTMIXEJ9YXZ9PAU6JUB0CYYW&affid=growthte&affExtParam1=ENKR20250501A1426809534&affExtParam2=3563')
request1
# Out:
# <Response [200]>

# %%
request1.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Fli
# ...

# %%
soup=bs4.BeautifulSoup(request1.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
  reviews = soup.find_all('div', {'class': 'ZmyHeo'})
for review in reviews:
                print(review.get_text ()+ "\n\n")
# Out:
# Okay, This is a good looking and powerful grinder. I sure recommend this product.Except below points...  All satisfied.The noise of this grinder is heavy. (Its a new launch. Hence Philips could have worked better on the sound of this machine.)We can hear sound of a screw or something rolling inside the grinder when you shake it. (May be it's just only in our product)There were lot of scratches. (Packing could have done better by Philips).READ MORE
#
#
# Good productREAD MORE
#
#
# Excellent quality product. Beautiful color. Less noise.People those who complaining about noise,. please don't run the mixie without the jars. With Jars it's making low noise for its watts.One star less because of the chutney jar. its just 0.3 ltr. Could have been 0.5 ltr.READ MORE
#
#
# Philips name is enough👍👍 product is superb thanks  again FlipkartREAD MORE
#
#
# ...

# %%
ratings_elements = soup.findAll('div', {'class': 'ipqd2A'})
for rating_element in ratings_elements:
   
    print(rating_element.get_text()+"\n")
# Out:
# 4.3

# %%
individual_rating = soup.findAll('div', {'class': "XQDdHH Ga3i8K"})
for rating in individual_rating:
    print(rating.get_text() + "\n")
# Out:
# 4
#
# 5
#
# 4
#
# 4
#
# 4
#
# 5
#
# 4
#
# 4
#
# 4
#
# 4

# %%
custom_name=soup.findAll('p',{'class':'_2NsDsF AwS1CA'});
for cust_name in custom_name:
    print(cust_name.get_text()+"\n")
# Out:
# Jithin Antony
#
# Pooja Pawar
#
# GiriVV
#
# Ummey Habiba
#
# Ruchi Lohia
#
# Jyoti  Singh
#
# Dr. Mahroof T
#
# sudhir kumar nayak
#
# pruthvi j
#
# SUMAN BISWAS
